# %%
# !python3 '/content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/main.py' \
    --mode 'train' \
    --train_continue 'off' \
    --lr 2e-4 \
    --batch_size 10 \
    --num_epoch 100 \
    --ny 256 \
    --nx 256 \
    --nch 3 \
    --nker 32 \
    --network 'DeepEDN' \
    --data_dir '/content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/datasets/chest2cipher' \
    --ckpt_dir '/content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/checkpoint' \
    --log_dir '/content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/log' \
    --result_dir '/content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/result'
# Out:
# mode: train
# norm: inorm
# learning rate: 2.0000e-04
# batch size: 10
# number of epoch: 100
# task: DeepEDN
# opts: ['direction', array([0.])]
# network: DeepEDN
# learning type: residual
# data dir: /content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/datasets/chest2cipher
# ckpt dir: /content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/checkpoint
# log dir: /content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/log
# result dir: /content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/result
# device: cuda
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/main.py", line 40, in <module>
#     train(args)
#   File "/content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN/train.py", line 128, in train
#     optimR = torch.optim.Adam(netROI.parameters(), lr=lr, betas=(0.5, 0.999)) #ROI
# ...

# %% [markdown]
# # https://m.blog.naver.com/gyul611/221847629930

# %%
cd '/content/drive/MyDrive/Privacy-Preserving-GAN/DeepEDN'

# %%
# !git init

# %%
# !git config --global user.email "ark0723@gmail.com"
# !git config --global user.name "ark0723"

# %%
# !git add .

# %%
# !git commit -m "DeepEDN initialization"

# %%
#리모트 시 주소에 사용자 이름과 패스워드를 모두 적어야합니다.

# !git remote add origin https://ark0723:kr14021428!@github.com/ark0723/DeepEDN.git
# !git push -u origin master

# 이때 만약 “fatal: remote origin already exists” 라는 에러메시지가 뜨면 
# 기존 remote를 제거하고 다시 설정합니다.
# !git remote rm origin

# %%
# !git push -u origin master

# %%
# !git remote remove origin https://ark0723:kr14021428!@github.com/ark0723/DeepEDN.git

# %%
# !git remote remove ark0723
